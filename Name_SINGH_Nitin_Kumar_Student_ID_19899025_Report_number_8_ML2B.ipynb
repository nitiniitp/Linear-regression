# %% [markdown]
# Name: SINGH Nitin Kumar
#
# Student ID: 19899025
#
# Report number: 8

# %% [markdown]
# # Here I used Linear regression model
# I trained the data_learn by using Linear regression model and predicted output  by using data_test values. Whole code is written in Python and used google colab for run the code.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data_learn=pd.read_excel("/content/data_learn.xlsx")
data_learn
# Out:
#          X       Y
# 0  -1.8757  0.0337
# 1  -2.0882  0.5595
# 2   2.0424  0.1190
# 3  -2.4599 -0.0163
# 4   1.9449  0.5565
# 5   2.4078  0.9542
# 6   1.0252 -1.4930
# 7   0.2771 -0.2775
# 8  -2.1963  0.3910
# 9   1.8951  0.3476
# 10 -1.2067  2.1146
# 11 -1.6299  0.6501
# 12  0.0367  0.4587
# 13 -0.9817  1.9442
# 14  1.8546 -0.4926
# 15 -2.3789 -0.8495
# 16 -1.8335  0.5390
# 17 -2.7769  1.0382
# 18 -1.5785  1.0936
# 19 -2.7226  0.5414
# 20  0.0740 -0.0212
# 21 -2.3265  0.0256
# 22 -2.2789 -0.2110
# 23 -1.3549  1.0637
# 24 -0.4618  1.3194
# 25 -1.5002  0.9822
# 26 -0.7177  1.0561
# 27 -0.1443  0.4545
# 28 -1.4074  1.2341
# 29  1.0158 -1.2260
# 30  2.6421  0.6042
# 31  2.2736  0.3420
# 32  0.1861 -0.6365
# 33  1.2733 -1.3260
# 34 -1.7796  0.4362
# 35  2.4938  0.8248
# 36  0.0240  0.3316
# 37  1.5930 -0.8781
# 38 -2.6501  0.2072
# 39 -2.3315  0.0692
# 40 -2.0304 -0.2306
# 41 -2.9798  1.7750
# 42 -0.4056  1.0359
# 43 -2.3238  0.3113
# 44 -0.4707  1.2336
# 45  1.6469 -0.2580
# ...

# %%
data_learn.describe()
# Out:
#                X          Y
# count  50.000000  50.000000
# mean   -0.549878   0.310722
# std     1.734118   0.805315
# min    -2.979800  -1.493000
# 25%    -2.169275  -0.225250
# 50%    -0.849700   0.344800
# 75%     0.997200   0.921850
# max     2.642100   2.114600

# %%
data_test=pd.read_excel("/content/data_test.xlsx")
data_test
# Out:
#         X1
# 0   2.2649
# 1   1.1495
# 2  -0.5241
# 3   0.7103
# 4  -0.8734
# 5   0.3952
# 6   2.6729
# 7   1.1775
# 8  -1.6107
# 9  -0.2736
# 10  2.1444
# 11  0.7038
# 12  1.5641
# 13 -1.7824
# 14 -1.6709
# 15  0.1890
# 16  0.8997
# 17  0.2215
# 18  2.6558
# 19 -1.6631
# 20  1.6601
# 21 -0.5403
# 22  0.6653
# 23 -1.0928
# 24 -0.4663
# 25  2.6459
# 26 -0.7301
# 27 -1.5203
# 28  0.4218
# 29 -1.1852
# 30 -2.9977
# 31  2.6092
# 32 -0.9580
# 33  2.9297
# 34 -0.5148
# 35 -0.3290
# 36 -2.5882
# 37 -2.7422
# 38 -0.7142
# 39  2.5502
# 40 -0.9156
# 41 -2.8355
# 42 -2.6202
# 43  1.1847
# 44  2.8032
# 45 -0.9835
# 46  1.3391
# 47 -2.5726
# 48  1.9008
# 49 -1.1112

# %%
data_learn.plot(x='X', y='Y', style='o', legend=False)
plt.title("X vs Y")
plt.xlabel("X")
plt.ylabel("Y")
plt.xlim(-3,3)
plt.ylim(-3.1,3)
plt.show();

# %%
# Data Preparation
X = data_learn.iloc[:,:-1].values
Y = data_learn.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train )
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm.coef_)
# Out:
# [-106.57572623]

# %%
predictions = lm.predict(X_test)

# %%
X_test=data_test
data_test
# Out:
#         X1
# 0   2.2649
# 1   1.1495
# 2  -0.5241
# 3   0.7103
# 4  -0.8734
# 5   0.3952
# 6   2.6729
# 7   1.1775
# 8  -1.6107
# 9  -0.2736
# 10  2.1444
# 11  0.7038
# 12  1.5641
# 13 -1.7824
# 14 -1.6709
# 15  0.1890
# 16  0.8997
# 17  0.2215
# 18  2.6558
# 19 -1.6631
# 20  1.6601
# 21 -0.5403
# 22  0.6653
# 23 -1.0928
# 24 -0.4663
# 25  2.6459
# 26 -0.7301
# 27 -1.5203
# 28  0.4218
# 29 -1.1852
# 30 -2.9977
# 31  2.6092
# 32 -0.9580
# 33  2.9297
# 34 -0.5148
# 35 -0.3290
# 36 -2.5882
# 37 -2.7422
# 38 -0.7142
# 39  2.5502
# 40 -0.9156
# 41 -2.8355
# 42 -2.6202
# 43  1.1847
# 44  2.8032
# 45 -0.9835
# 46  1.3391
# 47 -2.5726
# 48  1.9008
# 49 -1.1112

# %%
import matplotlib as plt
plt.pyplot.scatter(Y_test, predictions)
plt.pyplot.ylabel('Predicted')
plt.pyplot.xlabel('Y test')
# Out:
# Text(0.5, 0, 'Y test')
